# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the .dta file
df = pd.read_stata('appendix-dataset.dta')

# Display the dataframe
df.describe()
# Out:
#            sales_raw  num_aff_raw         stocks  gross_prod_nonfin_d  \
# count    2311.000000  2232.000000    3181.000000         3.422000e+03
# mean     2897.062155    40.237455    1131.748446         7.240485e+11
# std     20137.669295   206.638488    7932.733765         1.805551e+12
# min         0.000000     0.000000     -68.099998         5.013115e+09
# 25%         0.000000     0.000000       0.000000         5.012295e+10
# 50%         0.000000     0.000000       0.000000         2.008655e+11
# 75%         0.802299     0.000000      46.616669         5.943852e+11
# max    430225.250000  3487.000000  191281.000000         1.224419e+13
#
#        num_aff_MandA   sales_MandA  sales_stocks         gdp_d       rgdpl_d  \
# count    2684.000000  2.694000e+03  2.730000e+03  3.422000e+03   3422.000000
# mean       40.811104  2.638988e+09  2.546514e+09  4.963205e+11  16854.523438
# std       190.439453  1.869285e+10  1.855238e+10  1.300813e+12  11105.680664
# ...

# %%
df
# Out:
#      ISO_o ISO_d     sales_raw  num_aff_raw       stocks  gross_prod_nonfin_d  \
# 0      AUS   ARG           NaN          NaN   816.200012         4.382323e+11
# 1      AUT   ARG     13.200000          NaN    30.199999         4.382323e+11
# 2      BEL   ARG    240.699997          NaN          NaN         4.382323e+11
# 3      BGR   ARG      0.000000          0.0     0.000000         4.382323e+11
# 4      BLR   ARG      0.000000          0.0     0.000000         4.382323e+11
# ...    ...   ...           ...          ...          ...                  ...
# 3417   TUN   ZAF      0.000000          0.0     0.000000         2.150317e+11
# 3418   TUR   ZAF           NaN          NaN          NaN         2.150317e+11
# 3419   URY   ZAF      0.000000          0.0     0.000000         2.150317e+11
# 3420   USA   ZAF  12873.200195        178.0  2740.666748         2.150317e+11
# 3421   VEN   ZAF      0.000000          0.0     0.000000         2.150317e+11
#
# ...
