# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
import time
import json
import tqdm

# %%
# # Define the log function to gather the log information
# def log(response,logfile,output_path=os.getcwd()):
#     # Open or create the csv file
#     if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
#         log = open(logfile,'a')
#     else: #If the log file does not exist, create it and make headers for the log variables
#         log = open(logfile,'w')
#         header = ['timestamp','status_code','length','output_file']
#         log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
#     # Gather log information
#     status_code = response.status_code #Status code from the request result
#     timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
#     length = len(response.text) #Length of the HTML-string
    
#     # Open the log file and append the gathered log information
#     with open(logfile,'a') as log:
#         log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %%
# # Multiple versions of the list
# dates = ['2023-12-19','2023-12-18','2023-12-08']
# links = []
# prototype = 'https://drafting.ecfr.gov/api/renderer/v1/content/drafting/2023-12-19/title-15?subtitle=B&chapter=VII&subchapter=C&part=744&appendix=Supplement%20No.%204%20to%20Part%20744'
# for date in dates:
#     url = prototype.replace('2023-12-19',date)
#     links.append(url)

# # Request information of the list
# list_htmls = []
# logfile = 'log.csv'
# for url in tqdm.tqdm(links):
#     try:
#        response = requests.get(url)
#     except Exception as e:
#         print(url)
#         print(e)
#         with open("list_htmls",'w') as l:
#             json.dump(list_htmls,l) # save as json file to retrieve laters
#         continue # continue to next iteration of url
#     html = response.text
#     list_htmls.append(html)
#     time.sleep(0.5)
#     log(response,logfile)

# %%
# # Table to include the entity list
# table = []

# # Parse data with BeautifulSoup
# soup = BeautifulSoup(response.content, 'html')
# articles = soup.find_all('')

# %% [markdown]
# {"id":"NK-2CUomiD2azL8hqw8gituB4",
# "caption":"JOINT STOCK COMPANY VOLOGODSKY OPTIKO MEKHANICHESKY FACTORY",
# "schema":"Organization",
# "properties":{
#     "alias":["AO Vologodsky Optiko Mekhanichesky Zavod","OAO VOMZ","AO VOMZ","JSC VOMZ"],"country":["ru"],
#     "name":["JOINT STOCK COMPANY VOLOGODSKY OPTIKO MEKHANICHESKY FACTORY","Joint Stock Company Vologda Optical and Mechanical Plant"],
#     "topics":["sanction"],
#     "addressEntity":[{
#         "id":"NK-cQ8qDwUtp4tb2V2w6dNe3m",
#         "caption":"54 Maltseva Street, Vologda, 160009",
#         "schema":"Address",
#         "properties":{
#                 "postalCode":["160009"],
#                 "region":["Vologda Oblast"],
#                 "country":["ru"],
#                 "street":["54 Maltseva Street"],
#                 "full":["54 Maltseva Street, Vologda, 160009"],
#                 "city":["Vologda"]},
#         "referents":["addr-b30ed756b373399981e7bd1a63857b01f813da57","addr-c41cc369036e653af5f83686e915cc2613e61d0d","NK-Sb5VaZnLsQXQWruxd2DH5J","addr-24b272a59b18e00518b64cf6bd7b90688781c9fe","addr-e2c464425e87434619621d825cf9c8cdd3058932","addr-904819dc1a7ca4fcc1c9209f1870b3584be187b1"],
#         "datasets":["us_trade_csl"],
#         "first_seen":"2023-07-27T12:05:34",
#         "last_seen":"2023-12-31T21:53:01",
#         "last_change":"2023-07-27T12:05:34",
#         "target":false
#     }],
#     "sanctions":[{
#         "id":"trade-csl-ac52683193e3875686e5e9dc9f59139e04188fe4",
#         "caption":"Sanction",
#         "schema":"Sanction",
#         "properties":{
#             "startDate":["2023-02-27"],
#             "provisions":["Policy of denial."],
#             "entity":["NK-2CUomiD2azL8hqw8gituB4"],
#             "country":["us"],
#             "sourceUrl":["https://www.bis.doc.gov/index.php/policy-guidance/lists-of-parties-of-concern/entity-list"],
#             "authorityId":["88 FR 12158"],
#             "authority":["Entity List (EL) - Bureau of Industry and Security"],
#             "reason":["For all items subject to the EAR. (See §§ 734.9(g),3 746.8(a)(3), and 744.21(b) of the EAR) This license requirement may be overcome by License Exception GOV under § 740.11(b)(2) and €."]},
#         "referents":[],
#         "datasets":["us_trade_csl"],
#         "first_seen":"2023-05-27T00:38:20",
#         "last_seen":"2023-12-31T21:53:01",
#         "last_change":"2023-06-07T00:03:13",
#         "target":false
#         }]
#     },
#     "referents":["ua-nazk-company-649","trade-csl-5632632ecaa64dbd9525e75e13be22c59a98cc4e4789e7b03f646e4a","permid-4297551618","rupep-company-30125","fr-ga-7085","ch-seco-69938","ua-nsdc-18695-akcionerne-tovaristvo-vologodskij-optiko-mehanicnij-zavod","ch-seco-61569","ja-mof-d686f57b979da86c4a48dafb75dc508491bbac31","ru-inn-3525023010","ofac-38140","ua-nabc-company-649-jsc-vologda-optical-and-mechanical-plant"],
#     "datasets":["us_trade_csl"],
#     "first_seen":"2023-04-20T09:52:21",
#     "last_seen":"2023-12-31T21:53:01",
#     "last_change":"2023-08-23T16:20:01",
#     "target":true
# }
#
# {"id":"NK-2CuKYqfhJyWG3ftTUrq25i",
# "caption":"SINOTECH INDUSTRY CO., LTD.",
# "schema":"Organization",
# "properties":{
#     "name":["SINOTECH INDUSTRY CO., LTD."],
#     "topics":["sanction"]},
# "referents":["ofac-16852"],
# "datasets":["us_trade_csl"],
# "first_seen":"2023-04-20T09:52:21",
# "last_seen":"2023-12-31T21:53:01",
# "last_change":"2023-08-23T16:20:01","
# target":true
# }
#
# {
#     "id":"NK-2KnApsUVLDRZ3g6fiGZusQ",
#     "caption":"Adimir OU",
#     "schema":"LegalEntity",
#     "properties":{
#         "name":["Adimir OU"],
#         "addressEntity":[
#             {
#                 "id":"addr-2ed47db526885bdc772eba894be093fff471bb7a",
#                 "caption":"Vabaohukooli tee 76-A9, Tallinn, 12015",
#                 "schema":"Address",
#                 "properties":{
#                     "country":["ee"],
#                     "full":["Vabaohukooli tee 76-A9, Tallinn, 12015"],
#                     "postalCode":["12015"],
#                     "street":["Vabaohukooli tee 76-A9, Tallinn"]
#                 },
#                 "referents":[],
#                 "datasets":["us_trade_csl"],
#                 "first_seen":"2023-07-27T12:05:34",
#                 "last_seen":"2023-12-31T21:53:01",
#                 "last_change":"2023-07-27T12:05:34",
#                 "target":false
#                 },
#                 {"id":"addr-770159879aed84cc2f0766420eb51f7d47a24dbb",
#                 "caption":"Peterburi Tee 47-210, Tallinn, 11415",
#                 "schema":"Address",
#                 "properties":{
#                     "country":["ee"],
#                     "postalCode":["11415"],
#                     "full":["Peterburi Tee 47-210, Tallinn, 11415"],
#                     "street":["Peterburi Tee 47-210, Tallinn"]},
#                     "referents":[],
#                     "datasets":["us_trade_csl"],
#                     "first_seen":"2023-07-27T12:05:34",
#                     "last_seen":"2023-12-31T21:53:01",
#                     "last_change":"2023-07-27T12:05:34",
#                     "target":false
#                 },
#                 {"id":"addr-f69eb29efa0bf7da786d074c65cc7a04e6c9e4ab",
#                 "caption":"Akadeemia Tee 21E, Tallinn, 12618",
#                 "schema":"Address",
#                 "properties":{
#                     "street":["Akadeemia Tee 21E, Tallinn"],
#                     "country":["ee"],
#                     "postalCode":["12618"],
#                     "full":["Akadeemia Tee 21E, Tallinn, 12618"]
#                 },
#                 "referents":[],
#                 "datasets":["us_trade_csl"],
#                 "first_seen":"2023-07-27T12:05:34",
#                 "last_seen":"2023-12-31T21:53:01",
#                 "last_change":"2023-07-27T12:05:34","target":false
#             }
#         ],
#         "topics":["sanction"],
#         "country":["ee"],
#         "sanctions":[
#             {
#                 "id":"trade-csl-6ab14c3bbb9481d43e02eb5a6682f145442959e7","
#                 caption":"Sanction",
#                 "schema":"Sanction",
#                 "properties":{
#                     "authority":["Entity List (EL) - Bureau of Industry and Security"],
#                     "startDate":["2022-03-09"],
#                     "entity":["NK-2KnApsUVLDRZ3g6fiGZusQ"],
#                     "reason":["For all items subject to the EAR.  (See §744.11 of the EAR)"],"provisions":["Policy of denial. See §§ 746.8(b) and 744.21(e)."],
#                     "sourceUrl":["https://www.bis.doc.gov/index.php/policy-guidance/lists-of-parties-of-concern/entity-list"],
#                     "authorityId":["87 FR 13141"],
#                     "country":["us"]
#                     },
#                 "referents":[],
#                 "datasets":["us_trade_csl"],
#                 "first_seen":"2023-05-27T00:38:20",
#                 "last_seen":"2023-12-31T21:53:01",
#                 "last_change":"2023-06-07T00:03:13",
#                 "target":false
#             }
#         ]
#     },
#     "referents":["ua-nazk-company-2435","trade-csl-d494aa3b12f989215eaba21b6328f4ad87d8058a1aec5cd508af3d57","ua-nsdc-18744-adimir-ou","ua-nabc-company-2435-adimir-ou","trade-csl-243c5a2ad9dfb3d2e182e6152ca0a732df7054b5"],
#     "datasets":["us_trade_csl"],
#     "first_seen":"2023-05-27T00:38:20",
#     "last_seen":"2023-12-31T21:53:01",
#     "last_change":"2023-08-23T16:20:01",
#     "target":true
# }
